# %% [markdown]
# ## Basic Authentication - Login website with API and Python library requests
#
# Created by [tanyongsheng.net](https://tanyongsheng.net)

# %% [markdown]
# Basic Authentication is a method for an HTTP user agent (e.g., a web browser) to provide a username and password when making a request.

# %% [markdown]
# Website: [web-scraping.dev](https://web-scraping.dev/login)
#
# <img src="../assets/static/web-scrapingdev-login-page.png" width="500" alt="Login page to web-scraping.dev"/>

# %%
import requests

url = "https://web-scraping.dev/api/login"

payload = 'username=user123&password=password'
headers = {
  'content-type': 'application/x-www-form-urlencoded',
  # 'cookie': 'auth=user123-secret-token',
  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36'
}

# we used a session object to preserve our login status and cookies
session = requests.Session()

response = session.request("POST", url, headers=headers, data=payload)

print(response.text)
# Out:
# <!doctype html>
# <html lang="en">
#   <head>
#     <meta charset="utf-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">
#     <link rel="stylesheet" href="https://web-scraping.dev/assets/css/main.css"/>
#     <link rel="stylesheet" href="https://web-scraping.dev/assets/css/bootstrap.min.css"/>
#     <link rel="stylesheet" href="https://web-scraping.dev/assets/css/bootstrap-icons.css"/>
#     <link rel="stylesheet" href="https://web-scraping.dev/assets/css/highlight-nord.css"/>
#     <link rel="icon" href="https://web-scraping.dev/assets/media/icon.png" type="image/png" />
#     <script src="https://web-scraping.dev/assets/js/cash.min.js"></script>
#     <script src="https://web-scraping.dev/assets/js/main.js"></script>
#     <script src="https://web-scraping.dev/assets/js/bootstrap.js"></script>
#
#
#
# <title>web-scraping.dev login</title>
# <meta name="description" content="Mock login page for web scraper testing" />
#
# ...

# %%
# use the same session object (which preserves login status) to 
# access the website that couldn't be accessed before login
response = session.request("GET", "https://web-scraping.dev/login")

# save the html file locally
with open("./html_files/test_success.htm", "wb") as file:
    file.write(response.content)

# %% [markdown]
# ## How to confirm we have successfully logged into the website

# %% [markdown]
# 1. Open the [newly created HTML file](./html_files/test_success.htm) here with a text editor.
# 2. Copy and paste the HTML code into an [HTML viewer](https://html.onlineviewer.net).
# 3. You will see a login success page, confirming that we have successfully logged into the website.
#
#
# <img src="../assets/static/login-via-api.png" width="500" alt="Login success to web-scraping.dev"/>

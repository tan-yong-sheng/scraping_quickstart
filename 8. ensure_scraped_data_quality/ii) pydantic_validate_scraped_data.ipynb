# %% [markdown]
# ## Using Pydantic for Validation and Cleaning of Scraped data
#
# Note: not to use list[Any] for building pydantic class model, because there is no type list for sqlalchemy, if you want to save data to database via SQLModel ORM
#
# Introduction:
# - In Python, we do not need to specify data type of the variable when declaring or using it. Example:
#
# ```python
# var = 100
# var = 'My name is Python'
# ```
#
#
# Reference:
# 1. Data validation using Pydantic https://medium.com/@mahimamanik.22/data-validation-using-pydantic-5e97fe93fc87

# %%
# %pip install requests
# %pip install lxml
# %pip install pandas
# %pip install watermark
# %pip install pydantic==2.3.0
# %pip install pydantic-core==2.6.3
# %pip install word2number
# %pip install tqdm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: requests in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (2.31.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from requests) (2.2.1)
# Requirement already satisfied: idna<4,>=2.5 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from requests) (3.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from requests) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from requests) (2024.2.2)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: lxml in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (5.1.0)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (2.2.1)
# Requirement already satisfied: numpy<2,>=1.22.4 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: tzdata>=2022.7 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from pandas) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from pandas) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: watermark in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (2.4.3)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from watermark) (59.6.0)
# Requirement already satisfied: ipython>=6.0 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from watermark) (8.22.2)
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/lib/python3/dist-packages (from watermark) (4.6.4)
# Requirement already satisfied: traitlets>=5.13.0 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from ipython>=6.0->watermark) (5.14.1)
# Requirement already satisfied: pygments>=2.4.0 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from ipython>=6.0->watermark) (2.17.2)
# Requirement already satisfied: matplotlib-inline in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from ipython>=6.0->watermark) (0.1.6)
# Requirement already satisfied: exceptiongroup in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from ipython>=6.0->watermark) (1.2.0)
# Requirement already satisfied: stack-data in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from ipython>=6.0->watermark) (0.6.3)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from ipython>=6.0->watermark) (3.0.43)
# Requirement already satisfied: jedi>=0.16 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from ipython>=6.0->watermark) (0.19.1)
# Requirement already satisfied: decorator in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from ipython>=6.0->watermark) (5.1.1)
# Requirement already satisfied: pexpect>4.3 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from ipython>=6.0->watermark) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.0->watermark) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.0->watermark) (0.7.0)
# Requirement already satisfied: wcwidth in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.0->watermark) (0.2.13)
# Requirement already satisfied: asttokens>=2.1.0 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from stack-data->ipython>=6.0->watermark) (2.4.1)
# Requirement already satisfied: pure-eval in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from stack-data->ipython>=6.0->watermark) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from stack-data->ipython>=6.0->watermark) (2.0.1)
# Requirement already satisfied: six>=1.12.0 in /usr/lib/python3/dist-packages (from asttokens>=2.1.0->stack-data->ipython>=6.0->watermark) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pydantic==2.3.0 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (2.3.0)
# Requirement already satisfied: typing-extensions>=4.6.1 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from pydantic==2.3.0) (4.10.0)
# Requirement already satisfied: pydantic-core==2.6.3 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from pydantic==2.3.0) (2.6.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from pydantic==2.3.0) (0.6.0)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pydantic-core==2.6.3 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (2.6.3)
# Requirement already satisfied: typing-extensions!=4.7.0,>=4.6.0 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from pydantic-core==2.6.3) (4.10.0)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: word2number in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (1.1)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tqdm in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (4.66.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### Scrape the website content

# %%
from pydantic import (BaseModel, 
                      validate_call,
                      computed_field, 
                      field_serializer,
                      HttpUrl,
                      )

class BookModel(BaseModel):
  price: str
  book_title: str
  book_url: str
  star_rating_class: str

  @computed_field
  @property
  def star_rating(self) -> str:
    return self.star_rating_class.replace("star-rating ","")

  @field_serializer('star_rating')
  def serialize_star_rating(star_rating: str) -> int:
    return w2n.word_to_num(star_rating)

# %%
# %%time

import requests
from lxml import html
from word2number import w2n # convert number words (eg. twenty one) to numeric digits (21)
import pandas
from typing import Union # add type hint
from tqdm import tqdm

class BookSpider:
    def __init__(self):
        self.base_url: AnyHttpUrl = "https://books.toscrape.com"
        self.session: requests.sessions.Session  = requests.Session()
        self.headers: dict[str, str] = {
            'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
            'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36'
            }
        self.bookmodel = BookModel

    # @validate_call(validate_return=True)
    def parse(self, page_num: int=50) -> list[BookModel]:
        results = []
        # loop the page number to scrape
        for page_num in tqdm(range(1,page_num)):
            url = self.base_url + f"/catalogue/page-{page_num}.html"
            output_data = self._fetch_data(url=url)
            validated_bookmodel_data = self._validate_bookmodel_data(output_data)
            results.append(validated_bookmodel_data)
        return results
            

    # @validate_call(validate_return=True)
    def _fetch_data(self, url: HttpUrl) -> list[dict]:
        response = self.session.request("GET", url)
        tree = html.fromstring(response.content)      
        
        price = tree.xpath("//article[@class='product_pod']//div[@class='product_price']\
            /p[@class='price_color']/text()")        
        book_title = tree.xpath("//article[@class='product_pod']/h3/a/text()")
        book_url = tree.xpath("//article[@class='product_pod']/h3/a/@href")
        star_rating_class = tree.xpath("//article[@class='product_pod']/p/@class")

        data_list = {
                    "price": price,
                    "star_rating_class": star_rating_class,
                    "book_url": book_url, 
                    "book_title": book_title,
                }
        data = pandas.DataFrame(data_list).to_dict(orient="records")
        return data


    # @validate_call(validate_return=True)
    def _validate_bookmodel_data(self, books_data: list[dict]) -> BookModel:
        # validate book data with pydantic
        validated_bookmodel_data_list = []
        for book in books_data:
            validated_bookmodel_data = self.bookmodel.model_validate(book).model_dump() ## model_dump is to compute field
            validated_bookmodel_data_list.append(validated_bookmodel_data)
        return validated_bookmodel_data


book_spider = BookSpider()
data_list = book_spider.parse()
# Out:
# 100%|██████████| 49/49 [00:03<00:00, 12.71it/s]
# CPU times: user 320 ms, sys: 12.8 ms, total: 333 ms
# Wall time: 3.86 s

# %%
import pandas

df = pandas.DataFrame(data_list)
df.explode(['price', 'book_title', 'book_url', 'star_rating_class', 'star_rating'])
# Out:
#      price                          book_title  \
# 0   £45.17             It's Only the Himalayas
# 1   £33.63             You can't bury them ...
# 2   £45.22          The Natural History of ...
# 3   £50.40             Rat Queens, Vol. 3: ...
# 4   £22.00               In the Country We ...
# 5   £28.09     Avatar: The Last Airbender: ...
# 6   £17.44                        The Stranger
# 7   £41.25              The Cookies & Cups ...
# 8   £30.25                        Mrs. Houdini
# 9   £42.16     Deliciously Ella Every Day: ...
# 10  £52.65              Why the Right Went ...
# 11  £54.04          The Rosie Project (Don ...
# 12  £45.21                    Take Me with You
# 13  £38.39   Naruto (3-in-1 Edition), Vol. ...
# 14  £47.02          Hush, Hush (Hush, Hush ...
# 15  £25.01            Cometh the Hour (The ...
# 16  £51.48         Angels & Demons (Robert ...
# 17  £46.29        The Silent Sister (Riley ...
# 18  £58.32              How to Speak Golf: ...
# 19  £47.67           Off the Hook (Fishing ...
# 20  £49.71  10-Day Green Smoothie Cleanse: ...
# 21  £33.23                 Don't Forget Steven
# 22  £39.67             Shadows of the Past ...
# 23  £10.29                   History of Beauty
# 24  £35.96                           The Whale
# 25  £32.38              Playing from the Heart
# 26  £25.77    Blue Like Jazz: Nonreligious ...
# 27  £15.42          The Collected Poems of ...
# 28  £56.88              A Year in Provence ...
# 29  £44.58                     The Expatriates
# 30  £15.52                   Kill the Boy Band
# 31  £51.22           America's War for the ...
# 32  £13.73                          Some Women
# 33  £50.44           Fruits Basket, Vol. 4 ...
# 34  £24.04           We Are All Completely ...
# 35  £23.59        The Smitten Kitchen Cookbook
# 36  £43.59                     The Lonely Ones
# 37  £26.33             The Day the Crayons ...
# 38  £46.45   Shopaholic & Baby (Shopaholic ...
# 39  £32.87               One for the Money ...
# 40  £53.04     Lady Renegades (Rebel Belle ...
# 41  £42.21          Golden (Heart of Dread ...
# 42  £36.17                              Cosmos
# 43  £56.58             Are We Smart Enough ...
# 44  £53.47             Girl Online On Tour ...
# 45  £29.45                    The Selfish Gene
# 46  £14.76             The Communist Manifesto
# 47  £52.94               One Second (Seven #7)
# 48  £40.28           Fruits Basket, Vol. 1 ...
#
#                                              book_url  star_rating_class  \
# 0               its-only-the-himalayas_981/index.html    star-rating Two
# 1         you-cant-bury-them-all-poems_961/index.html    star-rating Two
# 2   the-natural-history-of-us-the-fine-art-of-pret...  star-rating Three
# 3   rat-queens-vol-3-demons-rat-queens-collected-e...  star-rating Three
# 4   in-the-country-we-love-my-family-divided_901/i...   star-rating Four
# 5   avatar-the-last-airbender-smoke-and-shadow-par...    star-rating Two
# 6                         the-stranger_861/index.html   star-rating Four
# 7   the-cookies-cups-cookbook-125-sweet-savory-rec...    star-rating One
# 8                          mrs-houdini_821/index.html   star-rating Five
# 9   deliciously-ella-every-day-quick-and-easy-reci...  star-rating Three
# 10  why-the-right-went-wrong-conservatism-from-gol...   star-rating Four
# 11     the-rosie-project-don-tillman-1_761/index.html    star-rating One
# 12                    take-me-with-you_741/index.html  star-rating Three
# 13  naruto-3-in-1-edition-vol-14-includes-vols-40-...    star-rating Two
# 14               hush-hush-hush-hush-1_701/index.html  star-rating Three
# 15  cometh-the-hour-the-clifton-chronicles-6_681/i...  star-rating Three
# 16      angels-demons-robert-langdon-1_661/index.html  star-rating Three
# 17  the-silent-sister-riley-macpherson-1_641/index...   star-rating Five
# 18  how-to-speak-golf-an-illustrated-guide-to-link...   star-rating Five
# 19  off-the-hook-fishing-for-trouble-1_601/index.html  star-rating Three
# 20  10-day-green-smoothie-cleanse-lose-up-to-15-po...   star-rating Five
# 21                  dont-forget-steven_561/index.html    star-rating One
# 22   shadows-of-the-past-logan-point-1_541/index.html   star-rating Five
# 23                   history-of-beauty_521/index.html   star-rating Four
# 24                           the-whale_501/index.html   star-rating Four
# 25              playing-from-the-heart_481/index.html    star-rating One
# 26  blue-like-jazz-nonreligious-thoughts-on-christ...    star-rating One
# 27  the-collected-poems-of-wb-yeats-the-collected-...   star-rating Five
# 28       a-year-in-provence-provence-1_421/index.html   star-rating Four
# 29                     the-expatriates_401/index.html    star-rating Two
# 30                   kill-the-boy-band_381/index.html   star-rating Five
# 31  americas-war-for-the-greater-middle-east-a-mil...    star-rating Two
# 32                          some-women_341/index.html   star-rating Five
# 33  fruits-basket-vol-4-fruits-basket-4_321/index....   star-rating Four
# 34  we-are-all-completely-beside-ourselves_301/ind...    star-rating One
# 35        the-smitten-kitchen-cookbook_281/index.html    star-rating One
# 36                     the-lonely-ones_261/index.html   star-rating Five
# 37  the-day-the-crayons-came-home-crayons_241/inde...   star-rating Five
# 38        shopaholic-baby-shopaholic-5_221/index.html    star-rating Two
# 39  one-for-the-money-stephanie-plum-1_201/index.html    star-rating Two
# 40        lady-renegades-rebel-belle-3_181/index.html   star-rating Five
# 41             golden-heart-of-dread-3_161/index.html   star-rating Four
# 42                              cosmos_141/index.html    star-rating Two
# 43  are-we-smart-enough-to-know-how-smart-animals-...    star-rating One
# 44   girl-online-on-tour-girl-online-2_101/index.html    star-rating One
# 45                     the-selfish-gene_81/index.html    star-rating One
# 46              the-communist-manifesto_61/index.html  star-rating Three
# 47                   one-second-seven-7_41/index.html    star-rating Two
# 48  fruits-basket-vol-1-fruits-basket-1_21/index.html   star-rating Five
#
#     star_rating
# 0             2
# 1             2
# 2             3
# 3             3
# 4             4
# 5             2
# 6             4
# 7             1
# 8             5
# 9             3
# 10            4
# 11            1
# 12            3
# 13            2
# 14            3
# 15            3
# 16            3
# 17            5
# 18            5
# 19            3
# 20            5
# 21            1
# 22            5
# 23            4
# 24            4
# 25            1
# 26            1
# 27            5
# 28            4
# 29            2
# 30            5
# 31            2
# 32            5
# 33            4
# 34            1
# 35            1
# 36            5
# 37            5
# 38            2
# 39            2
# 40            5
# 41            4
# 42            2
# 43            1
# 44            1
# 45            1
# 46            3
# 47            2
# 48            5

# %% [markdown]
# ## Computing environment

# %%
# %load_ext watermark

# %watermark

# print out pypi packages used
# %watermark --iversions

# date
# %watermark -u -n -t -z
# Out:
# Last updated: 2024-03-10T15:16:34.648636+00:00
#
# Python implementation: CPython
# Python version       : 3.10.12
# IPython version      : 8.22.2
#
# Compiler    : GCC 11.4.0
# OS          : Linux
# Release     : 6.1.75-060175-generic
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 16
# Architecture: 64bit
#
# word2number: 1.1
# pandas     : 2.2.1
# requests   : 2.31.0
# lxml       : 5.1.0
#
# Last updated: Sun Mar 10 2024 15:16:34UTC

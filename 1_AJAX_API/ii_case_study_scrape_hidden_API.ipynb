# %% [markdown]
# ## Find hidden API in KLSEScreener
#
# Created by [tanyongsheng.net](https://tanyongsheng.net)

# %% [markdown]
# ----
#
# ### Introduction
# Modern websites use hidden APIs to render dynamic data on the fly through background requests. Often this is used in product pagination, search functionality and other dynamic page parts. Therefore, we will engage in reverse engineering to identify and extract data directly from the APIs.
#
# ### Target Website
# [KLSE Screener](https://www.klsescreener.com/v2/news)
#
# <img src="../assets/static/klsescreener-news-page.png" width=500px>

# %%
# %pip install pandas
# %pip install tqdm
# %pip install requests
# %pip install lxml
# Out:
# Requirement already satisfied: pandas in c:\users\yongsheng.tan\appdata\local\miniconda3\envs\test\lib\site-packages (2.2.0)
# Requirement already satisfied: numpy<2,>=1.22.4 in c:\users\yongsheng.tan\appdata\local\miniconda3\envs\test\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\yongsheng.tan\appdata\local\miniconda3\envs\test\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\yongsheng.tan\appdata\local\miniconda3\envs\test\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\yongsheng.tan\appdata\local\miniconda3\envs\test\lib\site-packages (from pandas) (2023.4)
# Requirement already satisfied: six>=1.5 in c:\users\yongsheng.tan\appdata\local\miniconda3\envs\test\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tqdm in c:\users\yongsheng.tan\appdata\local\miniconda3\envs\test\lib\site-packages (4.64.1)
# Requirement already satisfied: colorama in c:\users\yongsheng.tan\appdata\local\miniconda3\envs\test\lib\site-packages (from tqdm) (0.4.5)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: requests in c:\users\yongsheng.tan\appdata\local\miniconda3\envs\test\lib\site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\yongsheng.tan\appdata\local\miniconda3\envs\test\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yongsheng.tan\appdata\local\miniconda3\envs\test\lib\site-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\yongsheng.tan\appdata\local\miniconda3\envs\test\lib\site-packages (from requests) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yongsheng.tan\appdata\local\miniconda3\envs\test\lib\site-packages (from requests) (2024.2.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: lxml in c:\users\yongsheng.tan\appdata\local\miniconda3\envs\test\lib\site-packages (4.9.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas
import json
from tqdm import tqdm
import requests
import time
from lxml import etree

headers = {
  'accept': 'application/json, text/javascript, */*; q=0.01',
  'accept-language': 'en-US,en;q=0.9,zh-CN;q=0.8,zh;q=0.7',
  'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36',
  'x-requested-with': 'XMLHttpRequest',
}
params = {}
session = requests.Session()

def fetch_data(session, url, headers, params):
    response = session.request("GET", url, headers=headers, params=params)
    return response

def scrape_news(max_page_num):
  data_list = []
  #processed_df = pandas.DataFrame()
  for page_num in tqdm(range(1,max_page_num+1)):
    url = f"https://www.klsescreener.com/v2/news/index/{page_num}"
    response = fetch_data(session, url, headers, params)
    data = response.json()
    
    # loop to next page
    page_num += 1
    params["until"]= data["paging"]["until"]

    data_list.append(data)
  return data_list

news_data = scrape_news(20)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# 100%|██████████| 20/20 [00:06<00:00,  3.33it/s]

# %%
df = pandas.DataFrame(news_data)
pandas.json_normalize(df.to_dict(orient="records"),)
# Out:
#                                                  data  count  \
# 0   [{'News': {'id': '1287167', 'created': '2024-0...     20
# 1   [{'News': {'id': '1287123', 'created': '2024-0...     20
# 2   [{'News': {'id': '1287083', 'created': '2024-0...     20
# 3   [{'News': {'id': '1287031', 'created': '2024-0...     20
# 4   [{'News': {'id': '1286895', 'created': '2024-0...     20
# 5   [{'News': {'id': '1286809', 'created': '2024-0...     20
# 6   [{'News': {'id': '1286701', 'created': '2024-0...     20
# 7   [{'News': {'id': '1286661', 'created': '2024-0...     20
# 8   [{'News': {'id': '1286891', 'created': '2024-0...     20
# 9   [{'News': {'id': '1286843', 'created': '2024-0...     20
# 10  [{'News': {'id': '1286593', 'created': '2024-0...     20
# 11  [{'News': {'id': '1286541', 'created': '2024-0...     20
# 12  [{'News': {'id': '1286503', 'created': '2024-0...     20
# 13  [{'News': {'id': '1286829', 'created': '2024-0...     20
# 14  [{'News': {'id': '1286431', 'created': '2024-0...     20
# 15  [{'News': {'id': '1286397', 'created': '2024-0...     20
# 16  [{'News': {'id': '1286357', 'created': '2024-0...     20
# 17  [{'News': {'id': '1286317', 'created': '2024-0...     20
# 18  [{'News': {'id': '1286217', 'created': '2024-0...     20
# 19  [{'News': {'id': '1286199', 'created': '2024-0...     20
#
#                                                  html  paging.until
# 0       <div class="item figure flex-block">\n    ...    1709381760
# 1       <div class="item figure flex-block">\n    ...    1709368533
# 2       <div class="item figure flex-block">\n    ...    1709342522
# 3       <div class="item figure flex-block">\n    ...    1709308800
# 4       <div class="item figure flex-block">\n    ...    1709296726
# 5       <div class="item figure flex-block">\n    ...    1709294335
# 6       <div class="item figure flex-block">\n    ...    1709290706
# 7       <div class="item figure flex-block">\n    ...    1709287860
# 8       <div class="item figure flex-block">\n    ...    1709285046
# 9       <div class="item figure flex-block">\n    ...    1709283008
# 10      <div class="item figure flex-block">\n    ...    1709278905
# 11      <div class="item figure flex-block">\n    ...    1709272368
# 12      <div class="item figure flex-block">\n    ...    1709267797
# 13      <div class="item figure flex-block">\n    ...    1709264160
# 14      <div class="item figure flex-block">\n    ...    1709258598
# 15      <div class="item figure flex-block">\n    ...    1709256273
# 16      <div class="item figure flex-block">\n    ...    1709251984
# 17      <div class="item figure flex-block">\n    ...    1709226006
# 18      <div class="item figure flex-block">\n    ...    1709222400
# 19      <div class="item figure flex-block">\n    ...    1709211906

# %%
df = pandas.DataFrame(news_data)
df_new = pandas.json_normalize(df.to_dict(orient="records"), 
        record_path=['data'], meta=["count", "html","paging"],
        )
df_new
# Out:
#      News.id         News.created        News.modified News.category  \
# 0    1287167  2024-03-03 00:30:52  2024-03-03 00:30:52          国际财经
# 1    1287165  2024-03-03 00:30:51  2024-03-03 00:30:51          国际财经
# 2    1287163  2024-03-03 00:30:21  2024-03-03 00:30:21          财经新闻
# 3    1287161  2024-03-03 00:30:20  2024-03-03 00:30:20          财经新闻
# 4    1287159  2024-03-03 00:30:19  2024-03-03 00:30:19          财经新闻
# ..       ...                  ...                  ...           ...
# 395  1286169  2024-02-29 21:51:06  2024-03-01 11:34:32          Edge
# 396  1286165  2024-02-29 21:32:02  2024-03-01 11:30:29            新闻
# 397  1286163  2024-02-29 21:32:01  2024-03-01 11:04:42
# 398  1286161  2024-02-29 21:18:54  2024-03-03 02:46:13            新闻
# 399  1286773  2024-03-01 23:36:13  2024-03-01 23:36:20          企业动向
#
#     News.publisher_id                                         News.title  \
# 0                  64                             抢搭AI电动车热潮 台积电全球招募8000人
# 1                  64                                   创业容易传业难 大华银行愁继承人
# 2                  12                               培养更多技职毕业生 农业部重点发展4产业
# 3                  12                               加强与大马各领域合作 乌克兰致力重建经济
# 4                  12                              农业部拟稻米行动计划 供3月20日会议审议
# ..                ...                                                ...
# 395                52  Syariah Criminal Offences Enactment in Perak s...
# 396                52  DRB-Hicom posts RM26.5m net profit in 4Q amid ...
# 397                52  June 13 hearing for govt's application to stri...
# 398                53                            成本和燃油价格高涨 亚航长程末季净利暴跌82%
# 399                58                             联昌集团末季净利增29.5％ 派息25.5仙
#
#                                           News.summary       News.date_post  \
# 0    （台北3日讯）台积电搭上AI、电动车等热潮，全力大扩张，宣布要在台湾大手笔征才约1700人，...  2024-03-03 00:25:16
# 1    彭博评论打造一个庞大商业帝国是一回事，能否在家族内传承则是另一回事。在95岁的黄祖耀月初去世...  2024-03-03 00:22:17
# 2    莫哈末沙布（右二）参观农业专家博览会各个展位。（沙登2日讯）农业及粮食安全部长拿督斯里莫哈末...  2024-03-03 00:22:17
# 3    （吉隆坡2日讯）乌克兰准备加强与大马在各领域的交流并扩大合作，以致力于重建在过去两年因俄罗斯...  2024-03-03 00:22:17
# 4    （吉隆坡2日讯）农业及粮食安全部将与稻米及白米行业利益相关者，就稻谷收购价、供应因素、进口白...  2024-03-03 00:22:17
# ..                                                 ...                  ...
# 395  The Syariah Criminal Offences Enactment in Per...  2024-02-29 21:29:53
# 396  DRB-Hicom Bhd posted a net profit of RM26.47 m...  2024-02-29 21:26:04
# 397  The High Court has fixed June 13 to hear the g...  2024-02-29 21:15:00
# 398  （吉隆坡29日讯）尽管营业额大涨，但维护与检修成本增加、员工成本高涨，以及燃料成本上涨，重创...  2024-02-29 21:07:23
# 399  得益于非利息收入（NOII）增多，联昌集团（CIMB,1023,主板金融服务组）截至2023...  2024-02-29 21:05:06
#
#                                     News.thumbnail_url News.author  \
# 0    //images.weserv.nl/?url=//www.enanyang.my/site...
# 1    //images.weserv.nl/?url=//www.enanyang.my/site...
# 2    //images.weserv.nl/?url=//www.enanyang.my/site...
# 3    //images.weserv.nl/?url=//www.enanyang.my/site...
# 4    //images.weserv.nl/?url=//www.enanyang.my/site...
# ..                                                 ...         ...
# 395  https://assets.theedgemarkets.com/Saarani_shar...
# 396  https://assets.theedgemarkets.com/drb-hicom-2_...
# 397  https://assets.theedgemarkets.com/wayhta_theed...
# 398  https://assets.theedgemarkets.com/AirAsia-X_fu...
# 399  https://www.sinchew.com.my/wp-content/uploads/...
#
#          News.date_added                                       News.img_url  \
# 0    2024-03-03 00:25:16  https://www.enanyang.my/sites/default/files/st...
# 1    2024-03-03 00:22:17  https://www.enanyang.my/sites/default/files/st...
# 2    2024-03-03 00:22:17  https://www.enanyang.my/sites/default/files/st...
# 3    2024-03-03 00:22:17  https://www.enanyang.my/sites/default/files/st...
# 4    2024-03-03 00:22:17  https://www.enanyang.my/sites/default/files/st...
# ..                   ...                                                ...
# 395  2024-02-29 21:29:53  https://assets.theedgemarkets.com/Saarani_shar...
# 396  2024-02-29 21:26:04  https://assets.theedgemarkets.com/drb-hicom-2_...
# 397  2024-02-29 21:15:00  https://assets.theedgemarkets.com/wayhta_theed...
# 398  2024-02-29 21:07:23  https://assets.theedgemarkets.com/AirAsia-X_fu...
# 399  2024-02-29 21:05:06  https://www.sinchew.com.my/wp-content/uploads/...
#
#                                              0.content Publisher.id  \
# 0    <div><div><div><div><div><div><div><img loadin...           64
# 1    <div><div><div><div><div><div><div><img loadin...           64
# 2    <div><div><div><div><div><div><div><img loadin...           12
# 3    <div><div><div><p>（吉隆坡2日讯）乌克兰准备加强与大马在各领域的交流并扩大...           12
# 4    <div><div><div><p>（吉隆坡2日讯）农业及粮食安全部将与稻米及白米行业利益相...           12
# ..                                                 ...          ...
# 395  <div class=newsTextDataWrapInner><p>IPOH (Feb ...           52
# 396  <div class=newsTextDataWrapInner><p>KUALA LUMP...           52
# 397  <div class=newsTextDataWrapInner><p>KUALA LUMP...           52
# 398  <div class=newsTextDataWrapInner><p>（吉隆坡29日讯）尽...           53
# 399  <figure id="attachment_5429672" aria-described...           58
#
#     Publisher.name                                      Publisher.url count  \
# 0          Nanyang                    http://www.enanyang.my/财经/国际财经/    20
# 1          Nanyang                    http://www.enanyang.my/财经/国际财经/    20
# 2          Nanyang                     http://www.enanyang.my/财经/财经新闻    20
# 3          Nanyang                     http://www.enanyang.my/财经/财经新闻    20
# 4          Nanyang                     http://www.enanyang.my/财经/财经新闻    20
# ..             ...                                                ...   ...
# 395        TheEdge  http://www.theedgemarkets.com/categories/malaysia    20
# 396        TheEdge  http://www.theedgemarkets.com/categories/malaysia    20
# 397        TheEdge  http://www.theedgemarkets.com/categories/malaysia    20
# 398        TheEdge      http://www.theedgemarkets.com/categories/news    20
# 399        Sinchew       https://www.sinchew.com.my/category/财经/企业动向/    20
#
#                                                   html                 paging
# 0        <div class="item figure flex-block">\n    ...  {'until': 1709381760}
# 1        <div class="item figure flex-block">\n    ...  {'until': 1709381760}
# 2        <div class="item figure flex-block">\n    ...  {'until': 1709381760}
# 3        <div class="item figure flex-block">\n    ...  {'until': 1709381760}
# 4        <div class="item figure flex-block">\n    ...  {'until': 1709381760}
# ..                                                 ...                    ...
# 395      <div class="item figure flex-block">\n    ...  {'until': 1709211906}
# 396      <div class="item figure flex-block">\n    ...  {'until': 1709211906}
# 397      <div class="item figure flex-block">\n    ...  {'until': 1709211906}
# 398      <div class="item figure flex-block">\n    ...  {'until': 1709211906}
# 399      <div class="item figure flex-block">\n    ...  {'until': 1709211906}
#
# [400 rows x 19 columns]

# %% [markdown]
# ## Additional info: How to find hidden API endpoint via Chrome Developer Tool
#
# 1. Open the website: [https://www.klsescreener.com/v2/news](https://www.klsescreener.com/v2/news) in your Chrome browser and open the Chrome Developer Tools by pressing Ctrl + Shift + I on your keyboard.
#
# 2. Go to the "Network" tab in DevTools and select "Fetch/XHR".
#
# 3. Scroll down and load the next pagination to trigger the AJAX API request as below:
#
# <br>
# <img src="../assets/static/klsescreener-news-page-finding-API.jpg" width=500px alt="Quotes to scrape's scrolling page to find APIs">

# %% [markdown]
# ## Computing Environment

# %%
# %load_ext watermark

# %watermark

# print out pypi packages used
# %watermark --iversions

# date
# %watermark -u -n -t -z
# Out:
# Last updated: 2024-03-03T11:46:04.300811+08:00
#
# Python implementation: CPython
# Python version       : 3.9.16
# IPython version      : 8.8.0
#
# Compiler    : MSC v.1916 64 bit (AMD64)
# OS          : Windows
# Release     : 10
# Machine     : AMD64
# Processor   : Intel64 Family 6 Model 142 Stepping 12, GenuineIntel
# CPU cores   : 8
# Architecture: 64bit
#
#
# Last updated: Sun Mar 03 2024 11:46:04Malay Peninsula Standard Time

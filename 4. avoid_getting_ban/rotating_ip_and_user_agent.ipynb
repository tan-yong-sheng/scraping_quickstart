# %% [markdown]
# ## Rotating IP address when scraping

# %% [markdown]
# Reference:
# 1. Rotating Source IPs (Part 1) - AWS API Gateway https://bigb0sss.github.io/posts/redteam-rotate-ip-aws-gateway/
# 2. IP Rotation with Python https://sgino209.medium.com/ip-rotation-with-python-c8033a079f4d

# %%
# !pip install requests
# !pip install requests-ip-rotator
# Out:
# Requirement already satisfied: requests in c:\users\yongsheng.tan\appdata\local\miniconda3\envs\py3.10\lib\site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\yongsheng.tan\appdata\local\miniconda3\envs\py3.10\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yongsheng.tan\appdata\local\miniconda3\envs\py3.10\lib\site-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\yongsheng.tan\appdata\local\miniconda3\envs\py3.10\lib\site-packages (from requests) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yongsheng.tan\appdata\local\miniconda3\envs\py3.10\lib\site-packages (from requests) (2024.2.2)
# Collecting requests-ip-rotator
#   Downloading requests_ip_rotator-1.0.14-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: requests in c:\users\yongsheng.tan\appdata\local\miniconda3\envs\py3.10\lib\site-packages (from requests-ip-rotator) (2.31.0)
# Collecting boto3 (from requests-ip-rotator)
#   Downloading boto3-1.34.49-py3-none-any.whl.metadata (6.6 kB)
# Collecting botocore<1.35.0,>=1.34.49 (from boto3->requests-ip-rotator)
#   Downloading botocore-1.34.49-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\yongsheng.tan\appdata\local\miniconda3\envs\py3.10\lib\site-packages (from boto3->requests-ip-rotator) (1.0.1)
# Collecting s3transfer<0.11.0,>=0.10.0 (from boto3->requests-ip-rotator)
#   Downloading s3transfer-0.10.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\yongsheng.tan\appdata\local\miniconda3\envs\py3.10\lib\site-packages (from requests->requests-ip-rotator) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yongsheng.tan\appdata\local\miniconda3\envs\py3.10\lib\site-packages (from requests->requests-ip-rotator) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\yongsheng.tan\appdata\local\miniconda3\envs\py3.10\lib\site-packages (from requests->requests-ip-rotator) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yongsheng.tan\appdata\local\miniconda3\envs\py3.10\lib\site-packages (from requests->requests-ip-rotator) (2024.2.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\yongsheng.tan\appdata\local\miniconda3\envs\py3.10\lib\site-packages (from botocore<1.35.0,>=1.34.49->boto3->requests-ip-rotator) (2.8.2)
# Collecting urllib3<3,>=1.21.1 (from requests->requests-ip-rotator)
#   Downloading urllib3-2.0.7-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: six>=1.5 in c:\users\yongsheng.tan\appdata\local\miniconda3\envs\py3.10\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.35.0,>=1.34.49->boto3->requests-ip-rotator) (1.16.0)
# Downloading requests_ip_rotator-1.0.14-py3-none-any.whl (20 kB)
# Downloading boto3-1.34.49-py3-none-any.whl (139 kB)
#    ---------------------------------------- 0.0/139.3 kB ? eta -:--:--
#    ----------- ---------------------------- 41.0/139.3 kB 1.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 122.9/139.3 kB 2.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 122.9/139.3 kB 2.4 MB/s eta 0:00:01
#    -------------------------------------- 139.3/139.3 kB 827.5 kB/s eta 0:00:00
# Downloading botocore-1.34.49-py3-none-any.whl (12.0 MB)
#    ---------------------------------------- 0.0/12.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.0 MB ? eta -:--:--
#    ---------------------------------------- 0.1/12.0 MB 1.1 MB/s eta 0:00:11
#     --------------------------------------- 0.2/12.0 MB 1.4 MB/s eta 0:00:09
#     --------------------------------------- 0.2/12.0 MB 1.3 MB/s eta 0:00:09
#     --------------------------------------- 0.3/12.0 MB 1.1 MB/s eta 0:00:11
#    - -------------------------------------- 0.3/12.0 MB 1.2 MB/s eta 0:00:10
#    - -------------------------------------- 0.4/12.0 MB 1.1 MB/s eta 0:00:11
#    - -------------------------------------- 0.4/12.0 MB 1.1 MB/s eta 0:00:11
#    - -------------------------------------- 0.5/12.0 MB 1.0 MB/s eta 0:00:12
#    - -------------------------------------- 0.5/12.0 MB 1.1 MB/s eta 0:00:11
#    - -------------------------------------- 0.5/12.0 MB 1.0 MB/s eta 0:00:11
#    - -------------------------------------- 0.5/12.0 MB 1.0 MB/s eta 0:00:11
#    - -------------------------------------- 0.6/12.0 MB 924.8 kB/s eta 0:00:13
#    -- ------------------------------------- 0.6/12.0 MB 958.5 kB/s eta 0:00:12
#    -- ------------------------------------- 0.6/12.0 MB 903.1 kB/s eta 0:00:13
#    -- ------------------------------------- 0.8/12.0 MB 1.0 MB/s eta 0:00:11
#    -- ------------------------------------- 0.8/12.0 MB 1.0 MB/s eta 0:00:11
#    -- ------------------------------------- 0.9/12.0 MB 1.1 MB/s eta 0:00:11
#    -- ------------------------------------- 0.9/12.0 MB 1.1 MB/s eta 0:00:11
#    --- ------------------------------------ 0.9/12.0 MB 950.8 kB/s eta 0:00:12
#    --- ------------------------------------ 1.0/12.0 MB 993.3 kB/s eta 0:00:12
#    --- ------------------------------------ 1.1/12.0 MB 1.0 MB/s eta 0:00:11
#    --- ------------------------------------ 1.1/12.0 MB 1.0 MB/s eta 0:00:11
#    --- ------------------------------------ 1.1/12.0 MB 1.0 MB/s eta 0:00:11
#    --- ------------------------------------ 1.1/12.0 MB 1.0 MB/s eta 0:00:11
#    --- ------------------------------------ 1.2/12.0 MB 929.4 kB/s eta 0:00:12
#    ---- ----------------------------------- 1.3/12.0 MB 991.2 kB/s eta 0:00:11
#    ---- ----------------------------------- 1.3/12.0 MB 986.9 kB/s eta 0:00:11
#    ---- ----------------------------------- 1.3/12.0 MB 968.1 kB/s eta 0:00:11
#    ---- ----------------------------------- 1.4/12.0 MB 979.4 kB/s eta 0:00:11
#    ---- ----------------------------------- 1.4/12.0 MB 979.4 kB/s eta 0:00:11
#    ----- ---------------------------------- 1.5/12.0 MB 992.9 kB/s eta 0:00:11
#    ----- ---------------------------------- 1.6/12.0 MB 1.0 MB/s eta 0:00:11
#    ----- ---------------------------------- 1.7/12.0 MB 1.1 MB/s eta 0:00:10
#    ----- ---------------------------------- 1.7/12.0 MB 1.0 MB/s eta 0:00:10
#    ------ --------------------------------- 1.8/12.0 MB 1.1 MB/s eta 0:00:10
#    ------ --------------------------------- 1.9/12.0 MB 1.1 MB/s eta 0:00:10
#    ------ --------------------------------- 1.9/12.0 MB 1.1 MB/s eta 0:00:10
#    ------ --------------------------------- 1.9/12.0 MB 1.1 MB/s eta 0:00:10
#    ------ --------------------------------- 2.0/12.0 MB 1.0 MB/s eta 0:00:10
#    ------ --------------------------------- 2.1/12.0 MB 1.1 MB/s eta 0:00:10
#    ------ --------------------------------- 2.1/12.0 MB 1.1 MB/s eta 0:00:10
#    ------- -------------------------------- 2.2/12.0 MB 1.1 MB/s eta 0:00:10
#    ------- -------------------------------- 2.2/12.0 MB 1.1 MB/s eta 0:00:10
#    ------- -------------------------------- 2.2/12.0 MB 1.1 MB/s eta 0:00:10
#    ------- -------------------------------- 2.2/12.0 MB 1.0 MB/s eta 0:00:10
#    ------- -------------------------------- 2.2/12.0 MB 1.0 MB/s eta 0:00:10
#    ------- -------------------------------- 2.3/12.0 MB 1.0 MB/s eta 0:00:10
#    ------- -------------------------------- 2.3/12.0 MB 989.7 kB/s eta 0:00:10
#    -------- ------------------------------- 2.4/12.0 MB 1.0 MB/s eta 0:00:10
#    -------- ------------------------------- 2.5/12.0 MB 1.0 MB/s eta 0:00:10
#    -------- ------------------------------- 2.6/12.0 MB 1.1 MB/s eta 0:00:09
#    -------- ------------------------------- 2.6/12.0 MB 1.1 MB/s eta 0:00:09
#    -------- ------------------------------- 2.6/12.0 MB 1.0 MB/s eta 0:00:10
#    -------- ------------------------------- 2.7/12.0 MB 1.0 MB/s eta 0:00:10
#    --------- ------------------------------ 2.8/12.0 MB 1.1 MB/s eta 0:00:09
#    --------- ------------------------------ 2.9/12.0 MB 1.1 MB/s eta 0:00:09
#    ---------- ----------------------------- 3.0/12.0 MB 1.1 MB/s eta 0:00:09
#    ---------- ----------------------------- 3.1/12.0 MB 1.1 MB/s eta 0:00:09
#    ---------- ----------------------------- 3.1/12.0 MB 1.1 MB/s eta 0:00:09
#    ---------- ----------------------------- 3.1/12.0 MB 1.1 MB/s eta 0:00:09
#    ---------- ----------------------------- 3.2/12.0 MB 1.1 MB/s eta 0:00:08
#    ----------- ---------------------------- 3.4/12.0 MB 1.1 MB/s eta 0:00:08
#    ----------- ---------------------------- 3.4/12.0 MB 1.1 MB/s eta 0:00:08
#    ----------- ---------------------------- 3.4/12.0 MB 1.1 MB/s eta 0:00:08
#    ----------- ---------------------------- 3.4/12.0 MB 1.1 MB/s eta 0:00:08
#    ----------- ---------------------------- 3.5/12.0 MB 1.1 MB/s eta 0:00:08
#    ----------- ---------------------------- 3.6/12.0 MB 1.1 MB/s eta 0:00:08
#    ----------- ---------------------------- 3.6/12.0 MB 1.1 MB/s eta 0:00:08
#    ----------- ---------------------------- 3.6/12.0 MB 1.1 MB/s eta 0:00:08
#    ------------ --------------------------- 3.6/12.0 MB 1.1 MB/s eta 0:00:08
#    ------------ --------------------------- 3.7/12.0 MB 1.1 MB/s eta 0:00:08
#    ------------ --------------------------- 3.7/12.0 MB 1.1 MB/s eta 0:00:08
#    ------------ --------------------------- 3.8/12.0 MB 1.1 MB/s eta 0:00:08
#    ------------ --------------------------- 3.8/12.0 MB 1.1 MB/s eta 0:00:08
#    ------------ --------------------------- 3.9/12.0 MB 1.1 MB/s eta 0:00:08
#    ------------- -------------------------- 4.0/12.0 MB 1.1 MB/s eta 0:00:08
#    ------------- -------------------------- 4.1/12.0 MB 1.1 MB/s eta 0:00:08
#    ------------- -------------------------- 4.1/12.0 MB 1.1 MB/s eta 0:00:08
#    ------------- -------------------------- 4.1/12.0 MB 1.1 MB/s eta 0:00:08
#    ------------- -------------------------- 4.1/12.0 MB 1.1 MB/s eta 0:00:08
#    ------------- -------------------------- 4.1/12.0 MB 1.1 MB/s eta 0:00:08
#    ------------- -------------------------- 4.1/12.0 MB 1.1 MB/s eta 0:00:08
#    ------------- -------------------------- 4.1/12.0 MB 1.1 MB/s eta 0:00:08
#    ------------- -------------------------- 4.1/12.0 MB 1.1 MB/s eta 0:00:08
#    ------------- -------------------------- 4.1/12.0 MB 1.1 MB/s eta 0:00:08
#    ------------- -------------------------- 4.1/12.0 MB 1.1 MB/s eta 0:00:08
#    ------------- -------------------------- 4.1/12.0 MB 1.1 MB/s eta 0:00:08
#    ------------- -------------------------- 4.1/12.0 MB 1.1 MB/s eta 0:00:08
#    ------------- -------------------------- 4.1/12.0 MB 1.1 MB/s eta 0:00:08
#    ------------- -------------------------- 4.2/12.0 MB 967.5 kB/s eta 0:00:09
#    ------------- -------------------------- 4.2/12.0 MB 963.0 kB/s eta 0:00:09
#    ------------- -------------------------- 4.2/12.0 MB 963.0 kB/s eta 0:00:09
#    ------------- -------------------------- 4.2/12.0 MB 963.0 kB/s eta 0:00:09
#    -------------- ------------------------- 4.3/12.0 MB 954.6 kB/s eta 0:00:09
#    -------------- ------------------------- 4.4/12.0 MB 967.3 kB/s eta 0:00:08
#    -------------- ------------------------- 4.5/12.0 MB 978.7 kB/s eta 0:00:08
#    --------------- ------------------------ 4.5/12.0 MB 972.0 kB/s eta 0:00:08
#    --------------- ------------------------ 4.6/12.0 MB 973.1 kB/s eta 0:00:08
#    --------------- ------------------------ 4.6/12.0 MB 984.2 kB/s eta 0:00:08
#    --------------- ------------------------ 4.7/12.0 MB 979.7 kB/s eta 0:00:08
#    --------------- ------------------------ 4.8/12.0 MB 987.4 kB/s eta 0:00:08
#    ---------------- ----------------------- 4.9/12.0 MB 1.0 MB/s eta 0:00:08
#    ---------------- ----------------------- 4.9/12.0 MB 1.0 MB/s eta 0:00:08
#    ---------------- ----------------------- 4.9/12.0 MB 990.3 kB/s eta 0:00:08
#    ---------------- ----------------------- 4.9/12.0 MB 985.1 kB/s eta 0:00:08
#    ---------------- ----------------------- 5.0/12.0 MB 980.0 kB/s eta 0:00:08
#    ---------------- ----------------------- 5.0/12.0 MB 983.0 kB/s eta 0:00:08
#    ----------------- ---------------------- 5.1/12.0 MB 993.0 kB/s eta 0:00:07
#    ----------------- ---------------------- 5.2/12.0 MB 993.9 kB/s eta 0:00:07
#    ----------------- ---------------------- 5.2/12.0 MB 988.9 kB/s eta 0:00:07
#    ----------------- ---------------------- 5.2/12.0 MB 990.8 kB/s eta 0:00:07
#    ----------------- ---------------------- 5.3/12.0 MB 978.3 kB/s eta 0:00:07
#    ----------------- ---------------------- 5.3/12.0 MB 970.7 kB/s eta 0:00:07
#    ----------------- ---------------------- 5.3/12.0 MB 973.6 kB/s eta 0:00:07
#    ------------------ --------------------- 5.4/12.0 MB 978.3 kB/s eta 0:00:07
#    ------------------ --------------------- 5.4/12.0 MB 977.6 kB/s eta 0:00:07
#    ------------------ --------------------- 5.5/12.0 MB 979.3 kB/s eta 0:00:07
#    ------------------ --------------------- 5.5/12.0 MB 972.2 kB/s eta 0:00:07
#    ------------------ --------------------- 5.5/12.0 MB 969.6 kB/s eta 0:00:07
#    ------------------ --------------------- 5.7/12.0 MB 981.3 kB/s eta 0:00:07
#    ------------------- -------------------- 5.8/12.0 MB 999.0 kB/s eta 0:00:07
#    ------------------- -------------------- 5.9/12.0 MB 1.0 MB/s eta 0:00:07
#    ------------------- -------------------- 5.9/12.0 MB 1.0 MB/s eta 0:00:07
#    ------------------- -------------------- 6.0/12.0 MB 1.0 MB/s eta 0:00:06
#    -------------------- ------------------- 6.0/12.0 MB 999.1 kB/s eta 0:00:06
#    -------------------- ------------------- 6.0/12.0 MB 999.1 kB/s eta 0:00:06
#    -------------------- ------------------- 6.1/12.0 MB 1.0 MB/s eta 0:00:06
#    -------------------- ------------------- 6.3/12.0 MB 1.0 MB/s eta 0:00:06
#    --------------------- ------------------ 6.3/12.0 MB 1.0 MB/s eta 0:00:06
#    --------------------- ------------------ 6.5/12.0 MB 1.0 MB/s eta 0:00:06
#    --------------------- ------------------ 6.5/12.0 MB 1.0 MB/s eta 0:00:06
#    --------------------- ------------------ 6.6/12.0 MB 1.0 MB/s eta 0:00:06
#    ---------------------- ----------------- 6.7/12.0 MB 1.0 MB/s eta 0:00:06
#    ---------------------- ----------------- 6.8/12.0 MB 1.0 MB/s eta 0:00:05
#    ----------------------- ---------------- 6.9/12.0 MB 1.1 MB/s eta 0:00:05
#    ----------------------- ---------------- 7.1/12.0 MB 1.1 MB/s eta 0:00:05
#    ----------------------- ---------------- 7.1/12.0 MB 1.1 MB/s eta 0:00:05
#    ----------------------- ---------------- 7.1/12.0 MB 1.1 MB/s eta 0:00:05
#    ------------------------ --------------- 7.2/12.0 MB 1.1 MB/s eta 0:00:05
#    ------------------------ --------------- 7.4/12.0 MB 1.1 MB/s eta 0:00:05
#    ------------------------- -------------- 7.5/12.0 MB 1.1 MB/s eta 0:00:05
#    ------------------------- -------------- 7.6/12.0 MB 1.1 MB/s eta 0:00:05
#    ------------------------- -------------- 7.6/12.0 MB 1.1 MB/s eta 0:00:05
#    ------------------------- -------------- 7.6/12.0 MB 1.1 MB/s eta 0:00:05
#    ------------------------- -------------- 7.6/12.0 MB 1.1 MB/s eta 0:00:05
#    ------------------------- -------------- 7.7/12.0 MB 1.1 MB/s eta 0:00:04
#    -------------------------- ------------- 7.8/12.0 MB 1.1 MB/s eta 0:00:04
#    -------------------------- ------------- 7.8/12.0 MB 1.1 MB/s eta 0:00:04
#    -------------------------- ------------- 7.9/12.0 MB 1.1 MB/s eta 0:00:04
#    -------------------------- ------------- 7.9/12.0 MB 1.1 MB/s eta 0:00:04
#    -------------------------- ------------- 7.9/12.0 MB 1.1 MB/s eta 0:00:04
#    -------------------------- ------------- 7.9/12.0 MB 1.1 MB/s eta 0:00:04
#    -------------------------- ------------- 8.0/12.0 MB 1.1 MB/s eta 0:00:04
#    --------------------------- ------------ 8.1/12.0 MB 1.1 MB/s eta 0:00:04
#    --------------------------- ------------ 8.2/12.0 MB 1.1 MB/s eta 0:00:04
#    --------------------------- ------------ 8.4/12.0 MB 1.1 MB/s eta 0:00:04
#    --------------------------- ------------ 8.4/12.0 MB 1.1 MB/s eta 0:00:04
#    ---------------------------- ----------- 8.4/12.0 MB 1.1 MB/s eta 0:00:04
#    ---------------------------- ----------- 8.5/12.0 MB 1.1 MB/s eta 0:00:04
#    ---------------------------- ----------- 8.6/12.0 MB 1.1 MB/s eta 0:00:04
#    ---------------------------- ----------- 8.7/12.0 MB 1.1 MB/s eta 0:00:03
#    ----------------------------- ---------- 8.8/12.0 MB 1.1 MB/s eta 0:00:03
#    ----------------------------- ---------- 8.8/12.0 MB 1.1 MB/s eta 0:00:03
#    ----------------------------- ---------- 8.8/12.0 MB 1.1 MB/s eta 0:00:03
#    ----------------------------- ---------- 8.8/12.0 MB 1.1 MB/s eta 0:00:03
#    ------------------------------ --------- 9.0/12.0 MB 1.1 MB/s eta 0:00:03
#    ------------------------------ --------- 9.1/12.0 MB 1.1 MB/s eta 0:00:03
#    ------------------------------ --------- 9.2/12.0 MB 1.1 MB/s eta 0:00:03
#    ------------------------------ --------- 9.3/12.0 MB 1.1 MB/s eta 0:00:03
#    ------------------------------- -------- 9.3/12.0 MB 1.1 MB/s eta 0:00:03
#    ------------------------------- -------- 9.5/12.0 MB 1.1 MB/s eta 0:00:03
#    -------------------------------- ------- 9.7/12.0 MB 1.2 MB/s eta 0:00:03
#    -------------------------------- ------- 9.7/12.0 MB 1.2 MB/s eta 0:00:02
#    -------------------------------- ------- 9.8/12.0 MB 1.2 MB/s eta 0:00:02
#    --------------------------------- ------ 9.9/12.0 MB 1.2 MB/s eta 0:00:02
#    --------------------------------- ------ 10.0/12.0 MB 1.2 MB/s eta 0:00:02
#    --------------------------------- ------ 10.1/12.0 MB 1.2 MB/s eta 0:00:02
#    --------------------------------- ------ 10.1/12.0 MB 1.2 MB/s eta 0:00:02
#    ---------------------------------- ----- 10.2/12.0 MB 1.2 MB/s eta 0:00:02
#    ---------------------------------- ----- 10.3/12.0 MB 1.2 MB/s eta 0:00:02
#    ---------------------------------- ----- 10.3/12.0 MB 1.2 MB/s eta 0:00:02
#    ---------------------------------- ----- 10.3/12.0 MB 1.2 MB/s eta 0:00:02
#    ----------------------------------- ---- 10.5/12.0 MB 1.2 MB/s eta 0:00:02
#    ----------------------------------- ---- 10.6/12.0 MB 1.2 MB/s eta 0:00:02
#    ----------------------------------- ---- 10.7/12.0 MB 1.2 MB/s eta 0:00:02
#    ------------------------------------ --- 10.8/12.0 MB 1.2 MB/s eta 0:00:01
#    ------------------------------------ --- 10.9/12.0 MB 1.2 MB/s eta 0:00:01
#    ------------------------------------ --- 10.9/12.0 MB 1.2 MB/s eta 0:00:01
#    ------------------------------------ --- 11.0/12.0 MB 1.2 MB/s eta 0:00:01
#    ------------------------------------- -- 11.2/12.0 MB 1.2 MB/s eta 0:00:01
#    ------------------------------------- -- 11.2/12.0 MB 1.2 MB/s eta 0:00:01
#    ------------------------------------- -- 11.2/12.0 MB 1.2 MB/s eta 0:00:01
#    ------------------------------------- -- 11.3/12.0 MB 1.2 MB/s eta 0:00:01
#    -------------------------------------- - 11.4/12.0 MB 1.2 MB/s eta 0:00:01
#    -------------------------------------- - 11.5/12.0 MB 1.2 MB/s eta 0:00:01
#    -------------------------------------- - 11.6/12.0 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  11.7/12.0 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  11.8/12.0 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  11.9/12.0 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  12.0/12.0 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 12.0/12.0 MB 1.3 MB/s eta 0:00:00
# Downloading s3transfer-0.10.0-py3-none-any.whl (82 kB)
#    ---------------------------------------- 0.0/82.1 kB ? eta -:--:--
#    ----------------------------- ---------- 61.4/82.1 kB 3.2 MB/s eta 0:00:01
#    ---------------------------------------- 82.1/82.1 kB 1.1 MB/s eta 0:00:00
# Downloading urllib3-2.0.7-py3-none-any.whl (124 kB)
#    ---------------------------------------- 0.0/124.2 kB ? eta -:--:--
#    ---------------------------------------  122.9/124.2 kB 3.6 MB/s eta 0:00:01
#    ---------------------------------------- 124.2/124.2 kB 1.8 MB/s eta 0:00:00
# Installing collected packages: urllib3, botocore, s3transfer, boto3, requests-ip-rotator
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.2.0
#     Uninstalling urllib3-2.2.0:
#       Successfully uninstalled urllib3-2.2.0
# Successfully installed boto3-1.34.49 botocore-1.34.49 requests-ip-rotator-1.0.14 s3transfer-0.10.0 urllib3-2.0.7

# %%
import requests
from urllib.parse import urlparse
from requests_ip_rotator import ApiGateway, EXTRA_REGIONS
aws_access_key_id = XXXXX
aws_secret_access_key = XXXXX

src = 'https://api64.ipify.org'
src_parsed = urlparse(src)
src_nopath = "%s://%s" % (src_parsed.scheme, src_parsed.netloc)
gateway1 = ApiGateway(src_nopath,                                           
                      regions=EXTRA_REGIONS,                                             
                      access_key_id=f"{aws_access_key_id}",                                             
                      access_key_secret=f"{aws_secret_access_key}")                       gateway1.start(force=True)

session1 = requests.Session()
session1.mount(src_nopath, gateway1)
try:
  r = session1.get(src, stream=True)
  file_request_succeed = r.ok
  if file_request_succeed:
    print('Rotated IP succeed')
except Exception as e:
  print('Rotated IP failed (%s)' % str(e))
  if proxy_rotation_mode == 'AWS':                          
    gateway1.shutdown()
# Out:
# Starting API gateways in 10 regions.
# ---------------------------------------------------------------------------
# NoCredentialsError                        Traceback (most recent call last)
# Cell In[4], line 6
#       4 # Create gateway object and initialise in AWS
#       5 gateway = ApiGateway("https://shareinvestor.com")
# ----> 6 gateway.start()
#       8 # Assign gateway to session
#       9 session = requests.Session()
#
# File c:\Users\yongsheng.tan\AppData\Local\miniconda3\envs\py3.10\lib\site-packages\requests_ip_rotator\ip_rotator.py:291, in ApiGateway.start(self, force, require_manual_deletion, endpoints)
#     289 # Get thread outputs
#     290 for future in concurrent.futures.as_completed(futures):
# --> 291     result = future.result()
#     292     if result["success"]:
#     293         self.endpoints.append(result["endpoint"])
#
# File c:\Users\yongsheng.tan\AppData\Local\miniconda3\envs\py3.10\lib\concurrent\futures\_base.py:451, in Future.result(self, timeout)
#     449     raise CancelledError()
#     450 elif self._state == FINISHED:
# --> 451     return self.__get_result()
#     453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File c:\Users\yongsheng.tan\AppData\Local\miniconda3\envs\py3.10\lib\concurrent\futures\_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File c:\Users\yongsheng.tan\AppData\Local\miniconda3\envs\py3.10\lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File c:\Users\yongsheng.tan\AppData\Local\miniconda3\envs\py3.10\lib\site-packages\requests_ip_rotator\ip_rotator.py:87, in ApiGateway.init_gateway(self, region, force, require_manual_deletion)
#      85 if not force:
#      86     try:
# ---> 87         current_apis = ApiGateway.get_gateways(awsclient)
#      88     except botocore.exceptions.ClientError as e:
#      89         if e.response["Error"]["Code"] == "UnrecognizedClientException":
#
# File c:\Users\yongsheng.tan\AppData\Local\miniconda3\envs\py3.10\lib\site-packages\requests_ip_rotator\ip_rotator.py:209, in ApiGateway.get_gateways(client)
#     204     gateways_response = client.get_rest_apis(
#     205         limit=500,
#     206         position=position
#     207     )
#     208 else:
# --> 209     gateways_response = client.get_rest_apis(
#     210         limit=500
#     211     )
#     213 gateways.extend(gateways_response['items'])
#     215 position = gateways_response.get('position', None)
#
# File c:\Users\yongsheng.tan\AppData\Local\miniconda3\envs\py3.10\lib\site-packages\botocore\client.py:553, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     549     raise TypeError(
#     550         f"{py_operation_name}() only accepts keyword arguments."
#     551     )
#     552 # The "self" in this scope is referring to the BaseClient.
# --> 553 return self._make_api_call(operation_name, kwargs)
#
# File c:\Users\yongsheng.tan\AppData\Local\miniconda3\envs\py3.10\lib\site-packages\botocore\client.py:989, in BaseClient._make_api_call(self, operation_name, api_params)
#     985     maybe_compress_request(
#     986         self.meta.config, request_dict, operation_model
#     987     )
#     988     apply_request_checksum(request_dict)
# --> 989     http, parsed_response = self._make_request(
#     990         operation_model, request_dict, request_context
#     991     )
#     993 self.meta.events.emit(
#     994     'after-call.{service_id}.{operation_name}'.format(
#     995         service_id=service_id, operation_name=operation_name
#    (...)
#    1000     context=request_context,
#    1001 )
#    1003 if http.status_code >= 300:
#
# File c:\Users\yongsheng.tan\AppData\Local\miniconda3\envs\py3.10\lib\site-packages\botocore\client.py:1015, in BaseClient._make_request(self, operation_model, request_dict, request_context)
#    1013 def _make_request(self, operation_model, request_dict, request_context):
#    1014     try:
# -> 1015         return self._endpoint.make_request(operation_model, request_dict)
#    1016     except Exception as e:
#    1017         self.meta.events.emit(
#    1018             'after-call-error.{service_id}.{operation_name}'.format(
#    1019                 service_id=self._service_model.service_id.hyphenize(),
#    (...)
#    1023             context=request_context,
#    1024         )
#
# File c:\Users\yongsheng.tan\AppData\Local\miniconda3\envs\py3.10\lib\site-packages\botocore\endpoint.py:119, in Endpoint.make_request(self, operation_model, request_dict)
#     113 def make_request(self, operation_model, request_dict):
#     114     logger.debug(
#     115         "Making request for %s with params: %s",
#     116         operation_model,
#     117         request_dict,
#     118     )
# --> 119     return self._send_request(request_dict, operation_model)
#
# File c:\Users\yongsheng.tan\AppData\Local\miniconda3\envs\py3.10\lib\site-packages\botocore\endpoint.py:198, in Endpoint._send_request(self, request_dict, operation_model)
#     196 context = request_dict['context']
#     197 self._update_retries_context(context, attempts)
# --> 198 request = self.create_request(request_dict, operation_model)
#     199 success_response, exception = self._get_response(
#     200     request, operation_model, context
#     201 )
#     202 while self._needs_retry(
#     203     attempts,
#     204     operation_model,
#    (...)
#     207     exception,
#     208 ):
#
# File c:\Users\yongsheng.tan\AppData\Local\miniconda3\envs\py3.10\lib\site-packages\botocore\endpoint.py:134, in Endpoint.create_request(self, params, operation_model)
#     130     service_id = operation_model.service_model.service_id.hyphenize()
#     131     event_name = 'request-created.{service_id}.{op_name}'.format(
#     132         service_id=service_id, op_name=operation_model.name
#     133     )
# --> 134     self._event_emitter.emit(
#     135         event_name,
#     136         request=request,
#     137         operation_name=operation_model.name,
#     138     )
#     139 prepared_request = self.prepare_request(request)
#     140 return prepared_request
#
# File c:\Users\yongsheng.tan\AppData\Local\miniconda3\envs\py3.10\lib\site-packages\botocore\hooks.py:412, in EventAliaser.emit(self, event_name, **kwargs)
#     410 def emit(self, event_name, **kwargs):
#     411     aliased_event_name = self._alias_event_name(event_name)
# --> 412     return self._emitter.emit(aliased_event_name, **kwargs)
#
# File c:\Users\yongsheng.tan\AppData\Local\miniconda3\envs\py3.10\lib\site-packages\botocore\hooks.py:256, in HierarchicalEmitter.emit(self, event_name, **kwargs)
#     245 def emit(self, event_name, **kwargs):
#     246     """
#     247     Emit an event by name with arguments passed as keyword args.
#     248
#    (...)
#     254              handlers.
#     255     """
# --> 256     return self._emit(event_name, kwargs)
#
# File c:\Users\yongsheng.tan\AppData\Local\miniconda3\envs\py3.10\lib\site-packages\botocore\hooks.py:239, in HierarchicalEmitter._emit(self, event_name, kwargs, stop_on_response)
#     237 for handler in handlers_to_call:
#     238     logger.debug('Event %s: calling handler %s', event_name, handler)
# --> 239     response = handler(**kwargs)
#     240     responses.append((handler, response))
#     241     if stop_on_response and response is not None:
#
# File c:\Users\yongsheng.tan\AppData\Local\miniconda3\envs\py3.10\lib\site-packages\botocore\signers.py:105, in RequestSigner.handler(self, operation_name, request, **kwargs)
#     100 def handler(self, operation_name=None, request=None, **kwargs):
#     101     # This is typically hooked up to the "request-created" event
#     102     # from a client's event emitter.  When a new request is created
#     103     # this method is invoked to sign the request.
#     104     # Don't call this method directly.
# --> 105     return self.sign(operation_name, request)
#
# File c:\Users\yongsheng.tan\AppData\Local\miniconda3\envs\py3.10\lib\site-packages\botocore\signers.py:195, in RequestSigner.sign(self, operation_name, request, region_name, signing_type, expires_in, signing_name)
#     192     else:
#     193         raise e
# --> 195 auth.add_auth(request)
#
# File c:\Users\yongsheng.tan\AppData\Local\miniconda3\envs\py3.10\lib\site-packages\botocore\auth.py:418, in SigV4Auth.add_auth(self, request)
#     416 def add_auth(self, request):
#     417     if self.credentials is None:
# --> 418         raise NoCredentialsError()
#     419     datetime_now = datetime.datetime.utcnow()
#     420     request.context['timestamp'] = datetime_now.strftime(SIGV4_TIMESTAMP)
#
# NoCredentialsError: Unable to locate credentials
